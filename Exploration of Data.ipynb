# %%
import os
import re
import string
import csv
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
# %matplotlib inline
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
 
chrome_options = Options()

browser = webdriver.Chrome(executable_path= os.getcwd()+'/chromedriver')
from pandas import *
import matplotlib.pyplot as plt
from sqlalchemy import *

from lxml import html
import requests

# %%
db2 = pd.read_csv('roles1.csv') #basic stats
db2.drop('Unnamed: 0',axis = 1, inplace = True)
db3 = pd.read_csv('roles2.csv') #basic stats
db3.drop('Unnamed: 0',axis = 1, inplace = True)

# %%
db2
# Out:
#                      Player  Role  MP_x   PER
# 0              Álex Abrines     4  19.0   6.3
# 1                Quincy Acy     4  12.3   2.9
# 2              Jaylen Adams     4  12.6   7.6
# 3              Steven Adams     2  33.4  18.5
# 4               Bam Adebayo     0  23.3  17.9
# 5                 Deng Adel     4  10.2   2.7
# 6    DeVaughn Akoon-Purcell     4   3.1   8.2
# 7         LaMarcus Aldridge     2  33.2  22.9
# 8              Rawle Alkins     4  12.0   8.1
# 9             Grayson Allen     4  10.9   7.5
# 10            Jarrett Allen     2  26.2  18.5
# 11             Kadeem Allen     5  21.9  16.2
# 12          Al-Farouq Aminu     2  28.3  13.2
# 13          Justin Anderson     4   9.6  11.2
# 14            Kyle Anderson     3  29.8  12.8
# 15            Ryan Anderson     4  12.9   4.6
# 16             Ike Anigbogu     6   2.0  -6.0
# 17    Giannis Antetokounmpo     7  32.8  30.9
# 18     Kostas Antetokounmpo     4   5.5  -0.9
# 19          Carmelo Anthony     7  29.4  10.9
# 20               OG Anunoby     7  20.2   9.8
# 21         Ryan Arcidiacono     7  24.2  11.6
# 22             Trevor Ariza     7  34.0  12.0
# 23            D.J. Augustin     5  28.0  15.7
# 24            Deandre Ayton     2  30.7  20.5
# 25             Dwayne Bacon     7  17.7  11.7
# 26            Marvin Bagley     7  25.3  18.9
# 27                Ron Baker     4  10.1   2.5
# 28             Wade Baldwin     4   5.9   1.3
# 29               Lonzo Ball     5  30.3  11.7
# ..                      ...   ...   ...   ...
# 500          Brad Wanamaker     4   9.5  14.3
# 501             T.J. Warren     2  31.6  16.3
# 502         Julian Washburn     4  14.1   6.5
# 503           Yuta Watanabe     4  11.6   3.3
# 504            Thomas Welsh     4   3.3  16.1
# 505       Russell Westbrook     5  36.0  21.1
# 506           Derrick White     3  25.8  14.8
# 507             Okaro White     4   2.0  -4.5
# 508        Hassan Whiteside     2  23.3  23.5
# 509          Andrew Wiggins     7  34.8  12.4
# 510           Alan Williams     0   5.2  32.9
# 511           C.J. Williams     7   8.5   8.8
# 512      Johnathan Williams     7  15.5  15.1
# 513        Kenrich Williams     7  23.5   9.7
# 514            Lou Williams     5  26.6  21.2
# 515         Marvin Williams     7  28.4  12.6
# 516         Robert Williams     7   8.8  18.8
# 517           Troy Williams     7  14.9  10.5
# 518             D.J. Wilson     7  18.4  10.3
# 519         Justise Winslow     7  29.7  12.8
# 520          Christian Wood     7  12.0  21.9
# 521            Delon Wright     7  22.7  15.5
# 522      Guerschon Yabusele     7   6.1  12.4
# 523              Nick Young     4   9.3   2.3
# 524          Thaddeus Young     2  30.7  16.2
# 525              Trae Young     5  30.9  17.0
# 526             Cody Zeller     2  25.4  17.2
# 527            Tyler Zeller     0  15.5  17.3
# 528              Ante Žižić     0  18.3  16.2
# 529             Ivica Zubac     0  17.6  18.9
#
# [530 rows x 4 columns]

# %%
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
count0 = 0

lista = []
listb = []
listc = []
listd = []
liste = []
listf = []
listg = []
listh = []

dbx = db2[db2['PER'] > 10.0]
for index,row in db2.iterrows():
    if(row['Role'] == 0):
        count0 = count0+1
        lista.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 1):
        count1 = count1+1
        listb.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 2):
        count2 = count2+1
        listc.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 3):
        count3 = count3+1
        listd.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 4):
        count4 = count4+1
        liste.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 5):
        count5 = count5+1
        listf.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 6):
        count6 = count6+1
        listg.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 7):
        count7 = count7+1
        listh.append(row['Player'])
for index,row in db2.iterrows():
    if(row['Role'] == 8):
        count8 = count8+1
for index,row in db2.iterrows():
    if(row['Role'] == 9):
        count9 = count9+1
for index,row in db2.iterrows():
    if(row['Role'] == 10):
        count10 = count10+1
print(count0)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
print(count6)
print(count7)
print(count8)
print(count9)
print(lista)
print(listb)
print(listc)
print(listd)
print(liste)
print(listf)
print(listg)
print(listh)
# Out:
# 89
# 13
# 61
# 161
# 101
# 61
# 4
# 40
# 0
# 0
# ['Bam Adebayo', 'Mo Bamba', 'Aron Baynes', 'Michael Beasley', 'Jordan Bell', 'Dragan Bender', 'Khem Birch', 'Bismack Biyombo', 'Jaron Blossomgame', 'Andrew Bogut', 'Jonah Bolden', 'Chris Boucher', 'Tony Bradley', 'Thomas Bryant', 'Omri Casspi', 'Troy Caupain', 'Tyson Chandler', 'Marquese Chriss', 'Zach Collins', 'Bonzie Colson', 'Mitch Creek', 'Deyonta Davis', 'Ed Davis', 'Marcus Derrickson', 'Cheick Diallo', 'Gorgui Dieng', 'PJ Dozier', 'Henry Ellenson', 'Drew Eubanks', 'Kenneth Faried', 'Cristiano Felício', 'Pau Gasol', 'Harry Giles', 'Marcin Gortat', 'Udonis Haslem', 'John Henson', 'Willy Hernangómez', 'Isaiah Hicks', 'Nenê Hilário', 'Richaun Holmes', 'Ersan İlyasova', 'Amile Jefferson', 'Jonas Jerebko', 'Alize Johnson', 'Amir Johnson', 'Jemerrio Jones', 'Kosta Koufos', 'Skal Labissière', 'T.J. Leaf', 'Alex Len', 'Meyers Leonard', 'Jon Leuer', 'Ian Mahinmi', 'Thon Maker', 'Boban Marjanović', 'Jarell Martin', 'Alfonzo McKinnie', 'Salah Mejri', 'Greg Monroe', 'Eric Moreland', 'Joakim Noah', 'Nerlens Noel', "Kyle O'Quinn", 'Jahlil Okafor', 'Zaza Pachulia', 'Justin Patton', 'Mason Plumlee', 'Miles Plumlee', 'Jakob Pöltl', 'Dwight Powell', 'Alex Poythress', 'Zhou Qi', 'Ivan Rabb', 'Devin Robinson', 'Mitchell Robinson', 'Thabo Sefolosha', 'Jason Smith', 'Ray Spalding', 'Omari Spellman', 'Caleb Swanigan', 'Emanuel Terry', 'Daniel Theis', 'Ekpe Udoh', 'Jarred Vanderbilt', 'Noah Vonleh', 'Alan Williams', 'Tyler Zeller', 'Ante Žižić', 'Ivica Zubac']
# ['Danny Green', 'Draymond Green', 'Gerald Green', 'JaMychal Green', 'Jeff Green', 'Blake Griffin', 'Tyus Jones', 'DeAndre Jordan', 'Cory Joseph', 'Frank Kaminsky', 'Enes Kanter', 'Luke Kennard', 'Michael Kidd-Gilchrist']
# ['Steven Adams', 'LaMarcus Aldridge', 'Jarrett Allen', 'Al-Farouq Aminu', 'Deandre Ayton', 'Harrison Barnes', 'Bojan Bogdanović', 'Malcolm Brogdon', 'Clint Capela', 'Wendell Carter', 'Willie Cauley-Stein', 'John Collins', 'DeMarcus Cousins', 'Robert Covington', 'Anthony Davis', 'Andre Drummond', 'Joel Embiid', 'Derrick Favors', 'Danilo Gallinari', 'Marc Gasol', 'Rudy Gay', 'Paul George', 'Taj Gibson', 'Rudy Gobert', 'Aaron Gordon', 'Jerami Grant', 'Montrezl Harrell', 'Tobias Harris', 'Buddy Hield', 'Al Horford', 'Dwight Howard', 'Serge Ibaka', 'Kyle Kuzma', 'Jeremy Lamb', 'Kawhi Leonard', 'Lauri Markkanen', 'JaVale McGee', 'Paul Millsap', 'Nikola Mirotić', 'Marcus Morris', 'Larry Nance', 'Jusuf Nurkić', 'Kelly Oubre', 'Jabari Parker', 'Otto Porter', 'Bobby Portis', 'Julius Randle', 'Domantas Sabonis', 'JaKarr Sampson', 'Pascal Siakam', 'Jayson Tatum', 'Klay Thompson', 'Tristan Thompson', 'Karl-Anthony Towns', 'Myles Turner', 'Jonas Valančiūnas', 'Nikola Vučević', 'T.J. Warren', 'Hassan Whiteside', 'Thaddeus Young', 'Cody Zeller']
# ['Kyle Anderson', 'Will Barton', 'Keita Bates-Diop', 'Nicolas Batum', 'Jerryd Bayless', 'Kent Bazemore', 'Malik Beasley', 'Marco Belinelli', "DeAndre' Bembry", 'Dāvis Bertāns', 'Patrick Beverley', 'Nemanja Bjelica', 'Avery Bradley', 'Corey Brewer', 'Mikal Bridges', 'Miles Bridges', 'Isaiah Briscoe', 'Dillon Brooks', 'Bruce Brown', 'Jaylen Brown', 'Sterling Brown', 'Troy Brown', 'Jalen Brunson', 'Reggie Bullock', 'Trey Burke', 'Alec Burks', 'Bruno Caboclo', 'Kentavious Caldwell-Pope', 'Isaiah Canaan', 'DeMarre Carroll', 'Vince Carter', 'Michael Carter-Williams', 'Alex Caruso', 'Wilson Chandler', 'Ian Clark', 'Pat Connaughton', 'Quinn Cook', 'Allen Crabbe', 'Torrey Craig', 'Jamal Crawford', 'Jae Crowder', 'Seth Curry', 'Matthew Dellavedova', 'Luol Deng', 'Donte DiVincenzo', 'Tyler Dorsey', 'Damyean Dotson', 'Jared Dudley', 'Wayne Ellington', 'James Ennis', 'Tyreke Evans', 'Dante Exum', 'Raymond Felton', 'Terrance Ferguson', 'Yogi Ferrell', 'Dorian Finney-Smith', 'Bryn Forbes', 'Tim Frazier', 'Markelle Fultz', 'Langston Galloway', 'Billy Garrett', 'Shai Gilgeous-Alexander', 'Eric Gordon', "Devonte' Graham", 'Treveon Graham', 'Jerian Grant', 'Maurice Harkless', 'Devin Harris', 'Gary Harris', 'Joe Harris', 'Shaquille Harrison', 'Josh Hart', 'Gordon Hayward', 'Juan Hernangómez', 'Mario Hezonja', 'George Hill', 'Solomon Hill', 'Aaron Holiday', 'Justin Holiday', 'Rondae Hollis-Jefferson', 'Rodney Hood', 'Danuel House', 'Kevin Huerter', 'Chandler Hutchison', 'Andre Iguodala', 'Josh Jackson', 'Justin Jackson', 'James Johnson', 'Stanley Johnson', 'Tyler Johnson', 'Damian Jones', 'Derrick Jones', 'Maxi Kleber', 'Brandon Knight', 'Kevin Knox', 'Furkan Korkmaz', 'Luke Kornet', 'Kyle Korver', 'Rodions Kurucs', 'Jake Layman', 'Jeremy Lin', 'Shaun Livingston', 'Frank Mason', 'Wesley Matthews', 'T.J. McConnell', 'Doug McDermott', 'Rodney McGruder', 'Jordan McRae', 'Jodie Meeks', "De'Anthony Melton", 'C.J. Miles', 'Darius Miller', 'Patty Mills', 'Shake Milton', 'Malik Monk', "E'Twaun Moore", 'Markieff Morris', 'Monte Morris', 'Mike Muscala', 'Shabazz Napier', 'Raul Neto', 'Dirk Nowitzki', 'Frank Ntilikina', 'David Nwaba', "Royce O'Neale", 'Elie Okobo', 'Josh Okogie', 'Kelly Olynyk', 'Cedi Osman', 'Chandler Parsons', 'Cameron Payne', 'Norman Powell', 'Chasson Randle', 'J.J. Redick', 'Austin Rivers', 'Terrence Ross', 'Terry Rozier', 'Dario Šarić', 'Tomáš Satoranský', 'Mike Scott', 'Wayne Selden', 'Landry Shamet', 'Iman Shumpert', 'Jonathon Simmons', 'Marcus Smart', 'Ish Smith', 'J.R. Smith', 'Zhaire Smith', 'Tony Snell', 'Nik Stauskas', 'Lance Stephenson', 'Garrett Temple', 'Lance Thomas', 'Anthony Tolliver', 'Allonzo Trier', 'P.J. Tucker', 'Evan Turner', 'Fred VanVleet', 'Dion Waiters', 'Taurean Waller-Prince', 'Derrick White']
# ['Álex Abrines', 'Quincy Acy', 'Jaylen Adams', 'Deng Adel', 'DeVaughn Akoon-Purcell', 'Rawle Alkins', 'Grayson Allen', 'Justin Anderson', 'Ryan Anderson', 'Kostas Antetokounmpo', 'Ron Baker', 'Wade Baldwin', 'Dairis Bertāns', 'Antonio Blakeney', 'Isaac Bonga', 'Ryan Broekhoff', 'MarShon Brooks', 'Lorenzo Brown', 'Deonte Burton', 'José Calderón', 'Jevon Carter', 'Tyler Cavanaugh', 'Joe Chealey', 'Chris Chiozza', 'Gary Clark', 'Dante Cunningham', 'Troy Daniels', 'Ángel Delgado', 'Hamidou Diallo', 'Vince Edwards', 'Jacob Evans', 'Jawun Evans', 'Melvin Frazier', 'Jimmer Fredette', 'Channing Frye', 'Brandon Goodwin', 'Daniel Hamilton', 'Dusty Hannahs', 'Andrew Harrison', 'Isaiah Hartenstein', 'Haywood Highsmith', 'John Holland', 'Isaac Humphries', 'Andre Ingram', 'John Jenkins', 'B.J. Johnson', 'Wesley Johnson', 'Jalen Jones', 'George King', 'Courtney Lee', 'Damion Lee', 'Zach Lofton', 'Daryl Macon', 'J.P. Macura', 'Yante Maten', 'Luc Mbah a Moute', 'Tahjere McCall', 'Patrick McCaw', 'Ben McLemore', 'Chimezie Metu', 'Malcolm Miller', 'Naz Mitrou-Long', 'Jaylen Morris', 'Donatas Motiejūnas', 'Džanan Musa', 'Sviatoslav Mykhailiuk', 'Abdel Nader', 'Georges Niang', 'James Nunnally', 'Semi Ojeleye', 'Patrick Patterson', 'Theo Pinson', 'Quincy Pondexter', 'Davon Reed', 'Cameron Reynolds', 'Malachi Richardson', 'Duncan Robinson', 'Glenn Robinson', 'Jerome Robinson', 'Brandon Sampson', 'Jordan Sibert', 'Kobi Simmons', 'Anfernee Simons', 'D.J. Stephens', 'Edmond Sumner', 'Miloš Teodosić', 'Jared Terrell', 'Isaiah Thomas', 'Khyri Thomas', 'Sindarius Thornwell', 'Gary Trent', 'Tyler Ulis', 'Moritz Wagner', 'Lonnie Walker', 'Tyrone Wallace', 'Brad Wanamaker', 'Julian Washburn', 'Yuta Watanabe', 'Thomas Welsh', 'Okaro White', 'Nick Young']
# ['Kadeem Allen', 'D.J. Augustin', 'Lonzo Ball', 'J.J. Barea', 'Bradley Beal', 'Eric Bledsoe', 'Bogdan Bogdanović', 'Devin Booker', 'Jimmy Butler', 'Jordan Clarkson', 'Darren Collison', 'Mike Conley', 'Stephen Curry', 'DeMar DeRozan', 'Spencer Dinwiddie', 'Luka Dončić', 'Goran Dragić', 'Kris Dunn', 'Kevin Durant', 'Trevon Duval', 'Evan Fournier', "De'Aaron Fox", 'Tim Hardaway', 'James Harden', 'Jrue Holiday', 'R.J. Hunter', 'Joe Ingles', 'Kyrie Irving', 'Reggie Jackson', 'LeBron James', 'Nikola Jokić', 'Zach LaVine', 'Walt Lemon', 'Caris LeVert', 'Damian Lillard', 'CJ McCollum', 'Khris Middleton', 'Donovan Mitchell', 'Emmanuel Mudiay', 'Jamal Murray', 'Victor Oladipo', 'Tony Parker', 'Chris Paul', 'Elfrid Payton', 'Gary Payton', 'Josh Richardson', 'Rajon Rondo', 'Derrick Rose', 'Ricky Rubio', "D'Angelo Russell", 'Dennis Schröder', 'Collin Sexton', 'Ben Simmons', 'Dennis Smith', 'Jeff Teague', 'Dwyane Wade', 'Kemba Walker', 'John Wall', 'Russell Westbrook', 'Lou Williams', 'Trae Young']
# ['Ike Anigbogu', 'Tyler Davis', 'Donte Grantham', 'Terrence Jones']
# ['Giannis Antetokounmpo', 'Carmelo Anthony', 'OG Anunoby', 'Ryan Arcidiacono', 'Trevor Ariza', 'Dwayne Bacon', 'Marvin Bagley', 'Dewayne Dedmon', 'Sam Dekker', 'Brandon Ingram', 'Jonathan Isaac', 'Wesley Iwundu', 'Demetrius Jackson', 'Frank Jackson', 'Jaren Jackson', 'Kevon Looney', 'Brook Lopez', 'Robin Lopez', 'Kevin Love', 'Kyle Lowry', 'Jordan Loyd', 'Kalin Lucas', 'Timothé Luwawu-Cabarrot', 'Tyler Lydon', 'Trey Lyles', 'Scott Machado', 'Shelvin Mack', 'Johnathan Motley', 'Andrew Wiggins', 'C.J. Williams', 'Johnathan Williams', 'Kenrich Williams', 'Marvin Williams', 'Robert Williams', 'Troy Williams', 'D.J. Wilson', 'Justise Winslow', 'Christian Wood', 'Delon Wright', 'Guerschon Yabusele']

# %%
count1 = 0
count2 = 0
count3 = 0
count4 = 0
count5 = 0
count6 = 0
count7 = 0
count8 = 0
count9 = 0
count0 = 0

lista = []
listb = []
listc = []
listd = []
liste = []
listf = []
listg = []
listh = []

for index,row in db3.iterrows():
    if(row['Role'] == 0):
        count0 = count0+1
        lista.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 1):
        count1 = count1+1
        listb.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 2):
        count2 = count2+1
        listc.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 3):
        count3 = count3+1
        listd.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 4):
        count4 = count4+1
        liste.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 5):
        count5 = count5+1
        listf.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 6):
        count6 = count6+1
        listg.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 7):
        count7 = count7+1
        listh.append(row['Player'])
for index,row in db3.iterrows():
    if(row['Role'] == 8):
        count8 = count8+1
for index,row in db3.iterrows():
    if(row['Role'] == 9):
        count9 = count9+1
for index,row in db3.iterrows():
    if(row['Role'] == 10):
        count10 = count10+1
print(count0)
print(count1)
print(count2)
print(count3)
print(count4)
print(count5)
print(count6)
print(count7)
print(count8)
print(count9)
print(lista)
print(listb)
print(listc)
print(listd)
print(liste)
print(listf)
print(listg)
print(listh)
# Out:
# 52
# 65
# 56
# 46
# 46
# 93
# 35
# 65
# 0
# 0
# ['Alex Abrines', 'Alfonzo McKinnie', 'Allen Crabbe', 'Andre Iguodala', 'Bonzie Colson', 'Brandon Sampson', 'Cameron Reynolds', 'Chandler Hutchison', 'Dairis Bertans', 'Damion Lee', 'Dante Cunningham', "De'Anthony Melton", 'Devin Harris', 'Dillon Brooks', 'Donte DiVincenzo', 'Doug McDermott', 'Duncan Robinson', 'Furkan Korkmaz', 'Glenn Robinson III', 'Grayson Allen', 'Hamidou Diallo', 'Ian Clark', 'Isaiah Thomas', 'JR Smith', 'Jordan McRae', 'Jose Calderon', 'Josh Hart', 'Julian Washburn', 'Keita Bates-Diop', 'Kenrich Williams', 'Langston Galloway', 'Malik Beasley', 'Marco Belinelli', 'Markelle Fultz', 'Mikal Bridges', 'Omri Casspi', 'Rawle Alkins', "Royce O'Neale", 'Ryan Broekhoff', 'Shake Milton', 'Solomon Hill', 'Thabo Sefolosha', 'Tony Snell', 'Torrey Craig', 'Treveon Graham', 'Troy Brown Jr.', 'Troy Daniels', 'Troy Williams', 'Tyrone Wallace', 'Walt Lemon Jr.', 'Wes Iwundu', 'Yuta Watanabe']
# ['Aaron Gordon', 'Andrew Wiggins', 'Anthony Davis', 'Ben Simmons', 'Blake Griffin', 'Bogdan Bogdanovic', 'Bojan Bogdanovic', 'Bradley Beal', 'Brandon Ingram', "D'Angelo Russell", 'Danilo Gallinari', 'Danny Green', 'DeMar DeRozan', 'Devin Booker', 'Draymond Green', 'Dwyane Wade', 'Emmanuel Mudiay', 'Eric Bledsoe', 'Evan Turner', 'Giannis Antetokounmpo', 'Gordon Hayward', 'Jake Layman', 'Jalen Brunson', 'James Harden', 'James Johnson', 'Jaylen Brown', 'Jayson Tatum', 'Jeff Green', 'Joel Embiid', 'Jonathan Isaac', 'Jordan Clarkson', 'Josh Jackson', 'Josh Richardson', 'Jrue Holiday', 'Julius Randle', 'Justise Winslow', 'Kawhi Leonard', 'Kelly Olynyk', 'Kevin Durant', 'Kevin Knox II', 'Khris Middleton', 'Klay Thompson', 'Kris Dunn', 'Kyle Kuzma', 'Kyrie Irving', 'Lauri Markkanen', 'LeBron James', 'Luka Doncic', 'Marcus Morris Sr.', 'Marcus Smart', 'Mario Hezonja', 'Miles Bridges', 'Nikola Jokic', 'Noah Vonleh', 'OG Anunoby', 'Pascal Siakam', 'Paul Millsap', 'Rudy Gay', 'Shaun Livingston', 'T.J. Warren', 'Tomas Satoransky', 'Trey Lyles', 'Tyreke Evans', 'Vince Carter', 'Zach LaVine']
# ['Abdel Nader', 'Alec Burks', 'Austin Rivers', 'Austin Rivers', 'Avery Bradley', 'Brandon Knight', 'Cameron Payne', 'Chris Paul', "DeAndre' Bembry", 'Delon Wright', 'Delon Wright', 'Dennis Schroder', 'Dennis Smith Jr.', 'Dennis Smith Jr.', 'Garrett Temple', 'George Hill', 'George Hill', 'Iman Shumpert', 'Isaiah Canaan', 'Jabari Parker', 'Jeremy Lin', 'Jeremy Lin', 'Jimmy Butler', 'Jimmy Butler', 'Jonathon Simmons', 'Justin Holiday', 'Kelly Oubre Jr.', 'Kelly Oubre Jr.', 'Kevin Huerter', 'Matthew Dellavedova', 'Mike Scott', 'Nik Stauskas', 'Paul George', 'Raymond Felton', 'Rodney Hood', 'Rodney Hood', 'Russell Westbrook', 'Shelvin Mack', 'Stanley Johnson', 'Stanley Johnson', 'Taurean Prince', 'Tim Frazier', 'Tim Frazier', 'Tim Hardaway Jr.', 'Tim Hardaway Jr.', 'Tobias Harris', 'Trae Young', 'Trevor Ariza', 'Trevor Ariza', 'Trey Burke', 'Trey Burke', 'Tyler Dorsey', 'Wayne Selden', 'Wayne Selden', 'Wesley Matthews', 'Wilson Chandler']
# ['Alec Burks', 'Avery Bradley', 'CJ Miles', 'CJ Miles', 'Corey Brewer', 'Corey Brewer', 'Courtney Lee', 'Courtney Lee', 'Daniel Hamilton', 'Dario Saric', 'Garrett Temple', 'Henry Ellenson', 'Iman Shumpert', 'Jalen Jones', 'James Ennis III', 'Jaylen Adams', 'John Jenkins', 'Jonathon Simmons', 'Justin Holiday', 'Justin Jackson', 'Justin Jackson', 'Kyle Korver', 'Landry Shamet', 'Landry Shamet', 'Michael Carter-Williams', 'Mike Muscala', 'Nik Stauskas', 'Otto Porter Jr.', 'Patrick McCaw', 'Reggie Bullock', 'Reggie Bullock', 'Robert Covington', 'Robert Covington', 'Ryan Anderson', 'Sam Dekker', 'Sam Dekker', 'Svi Mykhailiuk', 'Terrance Ferguson', 'Timothe Luwawu-Cabarrot', 'Tyler Johnson', 'Tyler Johnson', 'Wayne Ellington', 'Wayne Ellington', 'Wesley Johnson', 'Wesley Matthews', 'Wilson Chandler']
# ['Alex Len', 'Boban Marjanovic', 'Bobby Portis', 'Bobby Portis', 'Christian Wood', 'Dario Saric', 'DeAndre Jordan', 'DeAndre Jordan', 'DeMarcus Cousins', 'Enes Kanter', 'Enes Kanter', 'Gary Clark', 'Gorgui Dieng', 'Greg Monroe', 'Harrison Barnes', 'Harrison Barnes', 'Ivica Zubac', 'Ivica Zubac', 'JaMychal Green', 'JaMychal Green', 'Jabari Parker', 'James Ennis III', 'Jerami Grant', 'John Collins', 'Jon Leuer', 'Jonas Valanciunas', 'Jonas Valanciunas', 'Kenneth Faried', 'Kevin Love', 'Marc Gasol', 'Marc Gasol', 'Markieff Morris', 'Markieff Morris', 'Marquese Chriss', 'Mike Muscala', 'Mike Scott', 'Nikola Mirotic', 'Nikola Mirotic', 'Omari Spellman', 'Otto Porter Jr.', 'Patrick Patterson', 'Ray Spalding', 'Steven Adams', 'Taj Gibson', 'Tobias Harris', 'Tyson Chandler']
# ['Aaron Holiday', 'Alex Caruso', 'Allonzo Trier', 'Antonio Blakeney', 'Bruce Brown', 'Bryn Forbes', 'Buddy Hield', 'CJ McCollum', 'Caris LeVert', 'Chandler Parsons', 'Chasson Randle', 'Collin Sexton', 'Cory Joseph', 'D.J. Augustin', 'Damian Lillard', 'Damyean Dotson', 'Dante Exum', 'Danuel House Jr.', 'Darius Miller', 'Darren Collison', 'David Nwaba', "De'Aaron Fox", 'Derrick Rose', 'Derrick White', "Devonte' Graham", 'Dion Waiters', 'Donovan Mitchell', 'Dwayne Bacon', 'Elfrid Payton', 'Elie Okobo', 'Eric Gordon', 'Evan Fournier', 'Frank Jackson', 'Frank Mason', 'Frank Ntilikina', 'Fred VanVleet', 'Gary Harris', 'Gerald Green', 'Goran Dragic', 'Isaiah Briscoe', 'Ish Smith', 'J.J. Barea', 'Jamal Crawford', 'Jeff Teague', 'Jeremy Lamb', 'Jerian Grant', 'Jerryd Bayless', 'Jevon Carter', 'Joe Ingles', 'John Wall', 'Josh Okogie', 'Kadeem Allen', 'Kemba Walker', 'Kent Bazemore', 'Kyle Anderson', 'Kyle Lowry', 'Lance Stephenson', 'Lonzo Ball', 'Lou Williams', 'Luke Kennard', 'Malcolm Brogdon', 'Malik Monk', 'MarShon Brooks', 'Mike Conley', 'Monte Morris', 'Nicolas Batum', 'Norman Powell', 'Patrick Beverley', 'Patty Mills', 'Quinn Cook', 'Rajon Rondo', 'Raul Neto', 'Reggie Jackson', 'Ricky Rubio', 'Rodions Kurucs', 'Rodney McGruder', 'Ryan Arcidiacono', 'Seth Curry', 'Shabazz Napier', 'Shai Gilgeous-Alexander', 'Shaquille Harrison', 'Spencer Dinwiddie', 'Stephen Curry', 'Sterling Brown', 'T.J. McConnell', 'Terrence Ross', 'Terry Rozier', 'Theo Pinson', 'Tony Parker', 'Tyus Jones', 'Victor Oladipo', 'Will Barton', 'Yogi Ferrell']
# ['Al-Farouq Aminu', 'Alex Poythress', 'Amir Johnson', 'Anthony Tolliver', 'Bismack Biyombo', 'Bruno Caboclo', 'Cheick Diallo', 'D.J. Wilson', 'Damian Jones', 'Davis Bertans', 'DeMarre Carroll', 'Derrick Jones Jr.', 'Dorian Finney-Smith', "E'Twaun Moore", 'Ed Davis', 'Ian Mahinmi', 'JJ Redick', 'Jae Crowder', 'Jamal Murray', 'Jared Dudley', 'Jaron Blossomgame', 'Jarrett Allen', 'Joe Harris', 'Johnathan Williams', 'Jonah Bolden', 'Kentavious Caldwell-Pope', 'Kevon Looney', 'Khem Birch', 'Luke Kornet', 'Michael Kidd-Gilchrist', 'Nerlens Noel', 'P.J. Tucker', 'Pat Connaughton', 'Salah Mejri', 'Semi Ojeleye']
# ['Al Horford', 'Andre Drummond', 'Ante Zizic', 'Aron Baynes', 'Bam Adebayo', 'Brook Lopez', 'Carmelo Anthony', 'Clint Capela', 'Cody Zeller', 'Cristiano Felicio', 'Daniel Theis', 'Deandre Ayton', 'Derrick Favors', 'Dewayne Dedmon', 'Dirk Nowitzki', 'Domantas Sabonis', 'Dragan Bender', 'Dwight Powell', 'Ersan Ilyasova', 'Frank Kaminsky', 'Harry Giles III', 'Hassan Whiteside', 'Ivan Rabb', 'JaVale McGee', 'Jahlil Okafor', 'Jakob Poeltl', 'Jaren Jackson Jr.', 'Joakim Noah', 'Jonas Jerebko', 'Jordan Bell', 'Juancho Hernangomez', 'Jusuf Nurkic', 'Karl-Anthony Towns', 'Kosta Koufos', 'LaMarcus Aldridge', 'Lance Thomas', 'Larry Nance Jr.', 'Luol Deng', 'Marcin Gortat', 'Marvin Bagley III', 'Marvin Williams', 'Mason Plumlee', 'Maurice Harkless', 'Maxi Kleber', 'Meyers Leonard', 'Michael Beasley', 'Mitchell Robinson', 'Mo Bamba', 'Montrezl Harrell', 'Moritz Wagner', 'Myles Turner', 'Nemanja Bjelica', 'Nene', 'Nikola Vucevic', 'Richaun Holmes', 'Rondae Hollis-Jefferson', 'Rudy Gobert', 'Serge Ibaka', 'Thomas Bryant', 'Tristan Thompson', 'Wendell Carter Jr.', 'Willie Cauley-Stein', 'Willy Hernangomez', 'Zach Collins', 'Zaza Pachulia']
